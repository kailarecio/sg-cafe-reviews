# %% [markdown]
# ### import packages and env variables

# %%
import googlemaps
import os
import pandas as pd
import time
from dotenv import load_dotenv
import yaml
import json

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### load config

# %%
# load in yaml file
with open('config/neighborhoods.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %%
# flatten yaml file's contents
neighborhoods = []

for region, neighborhood in config.items():
    for name, details in neighborhood.items():
        details['neighborhood_name'] = name
        details['region'] = region
        neighborhoods.append(details)

print(f'Client initialized and cafe reviews for {len(neighborhoods)} neighborhoods will be extracted')

# %%
config['central']['cbd']
# Out:
# {'center': [1.2840355, 103.8420201], 'radius': 1200, 'region': 'central'}

# %%
config
# Out:
# {'central': {'cbd': {'center': [1.2840355, 103.8420201],
#    'radius': 1200,
#    'region': 'central'},
#   'bras_basah': {'center': [1.2958975, 103.8547797],
#    'radius': 1200,
#    'region': 'central'},
#   'orchard': {'center': [1.3028628, 103.8477971],
#    'radius': 1200,
#    'region': 'central'}},
#  'north': {'balestier': {'center': [1.3234477, 103.8480894],
#    'radius': 1200,
#    'region': 'north'},
#   'upper_thomson': {'center': [1.3545179, 103.8351714],
#    'radius': 1200,
#    'region': 'north'},
#   'serangoon_gardens': {'center': [1.360303, 103.8686115],
#    'radius': 1200,
#    'region': 'north'}},
#  'east': {'geylang': {'center': [1.314752, 103.8837181],
#    'radius': 1200,
#    'region': 'east'},
#   'katong': {'center': [1.3088691, 103.9044623],
#    'radius': 1200,
#    'region': 'east'},
#   'siglap': {'center': [1.3135075, 103.9256521],
#    'radius': 1200,
#    'region': 'east'}},
#  'west': {'holland_village': {'center': [1.3120885, 103.7958535],
#    'radius': 1200,
#    'region': 'west'},
#   'tiong_bahru': {'center': [1.2809413, 103.8226811],
#    'radius': 1200,
#    'region': 'west'},
#   'queenstown': {'center': [1.2872333, 103.7908553],
#    'radius': 1200,
#    'region': 'west'}}}

# %% [markdown]
# ### initialize client

# %%
# initialize client (have a separate dto for this later)
gmaps = googlemaps.Client(key=os.getenv('GOOGLE_MAPS_API_KEY'))

# %% [markdown]
# API reference: https://googlemaps.github.io/google-maps-services-python/docs/index.html

# %% [markdown]
# ### test

# %%
# Basic nearby search for cafes
cafes_result = gmaps.places_nearby(
    location=(1.3015, 103.8983),  # home
    radius=5000,  # in meters
    type='cafe',  # search key
    language='en'  # english
)

# convert results to list
cafes = cafes_result.get('results', [])
print(f"Found {len(cafes)} cafes")
# Out:
# Found 20 cafes

# %%
'reviews', 'rating', 'adr_address', 'opening_hours', 'name', 'wheelchair_accessible_entrance', 'geometry/viewport/northeast', 'serves_brunch', 
'geometry/viewport/southwest', 'current_opening_hours', 'geometry/viewport/northeast/lat', 'geometry/viewport/southwest/lng', 'utc_offset', 
'user_ratings_total', 'international_phone_number', 'secondary_opening_hours', 'review', 'serves_dinner', 'geometry/viewport/northeast/lng', 
'editorial_summary', 'geometry/viewport', 'geometry/location/lat', 'place_id', 'icon', 'serves_lunch', 'takeout', 'photo', 'vicinity', 
'curbside_pickup', 'delivery', 'dine_in', 'serves_wine', 'url', 'plus_code', 'serves_vegetarian_food', 'formatted_address', 'geometry/location/lng', 
'business_status', 'serves_beer', 'price_level', 'geometry/location', 'formatted_phone_number', 'website', 
'address_component', 'serves_breakfast', 'permanently_closed', 'geometry/viewport/southwest/lat', 'reservable', 'type', 'geometry'

# %%
# get unique identifier for each cafe
place_id = cafes[0]['place_id']

details = gmaps.place(
    place_id = place_id,
    fields = [
        # metadata
        'name', 
        'formatted_address',
        'geometry/location', # coordinates
        'opening_hours',

        # reviews/ratings
        'rating',
        'user_ratings_total',
        'reviews',

        # food
        'serves_brunch',
        'serves_lunch',
        'serves_dinner',
        'serves_breakfast',
        
        # others
        'price_level',  # 0-4 scale
        'type', 
        'business_status'
    ],
    language='en'
)

# %% [markdown]
# reviews[].text: actual content -- others: author_name, language, rating, relative_time_description, time
# - next steps: filter out OLD reviews

# %%
place_info = details.get('result', [])
reviews = place_info.get('reviews', [])
reviews
# Out:
# [{'author_name': 'Angel Somohano',
#   'author_url': 'https://www.google.com/maps/contrib/110743587808350855164/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVssnuYCdCcDk1Kjtk7JcaxqWxAmB2QDnrqt9ooKm6osFFm_-6m=s128-c0x00000000-cc-rp-mo-ba3',
#   'rating': 5,
#   'relative_time_description': 'in the last week',
#   'text': 'It Is Paradise for coffee lovers. We had a very delicious breakfast. Eggs, salmón Toast and pumpkin mushnroom Toast (incredible). The very foamy nitro cold brew deserves a #1 prize. I love this place!',
#   'time': 1758681760,
#   'translated': False},
#  {'author_name': 'Eric Lee',
#   'author_url': 'https://www.google.com/maps/contrib/113775188408100673442/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU2epHzdoE79ycVleKwVsaMMIVU5JaAP2-flhYJz8G_-sYdj13R=s128-c0x00000000-cc-rp-mo-ba6',
#   'rating': 4,
#   'relative_time_description': '2 months ago',
#   'text': 'This Cafe gets a solid four stars for the ambience and food that it delivers. From the outside, it looks really bad and run down. But the moment you step inside, it is a really hit café with a very large crowd. The food is actually quite expensive, but some of the dishes are quite good. A very nice hidden location where it is far away from town and only people who knows it will find it.',
#   'time': 1752292068,
#   'translated': False},
#  {'author_name': 'Neil Jimenez',
#   'author_url': 'https://www.google.com/maps/contrib/103931522674995265912/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXba19mLJIn-L499yIo93jG_T8SEpHImr4B2NFt5k2jjmGmS8ikGQ=s128-c0x00000000-cc-rp-mo-ba5',
#   'rating': 4,
#   'relative_time_description': 'a month ago',
#   'text': 'Finally returned to CSHH since 2019.\n\nTheir coffee game has improved. This time we had the pour overs. They have a decent selection with some beans having unique flavor notes. I liked it. The barista who prepared my coffee looked very professional and skilled.\n\nYou have the option to seat inside or outside. Because of the summer heat, I stayed inside.\n\nThey encourage to order via the QR code that leads you to their website where you can order and pay.\n\nSmooth and informative service. Not too crowded too.\n\nHighly recommend.',
#   'time': 1754799250,
#   'translated': False},
#  {'author_name': 'Wai Meng Yap',
#   'author_url': 'https://www.google.com/maps/contrib/107002775994730492083/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUgMIXCafvC9GKCPJE4XygNmToPi_Z_aabafUtuosGGveFLS0GmMw=s128-c0x00000000-cc-rp-mo-ba4',
#   'rating': 4,
#   'relative_time_description': '3 months ago',
#   'text': "The setting is cozy and reminds me of the cafes I visited in Bangkok and Malaysia (e.g. Factory and Soil). Food portions are big and taste great. I tried their latte (not too sweet), had a mushroom fete toast and a bucket of wigs to share. My family ordered different dishes - avocado toast, triple cheese sandwich and pasta. Food isn't too rich. Apparently their filter coffee is a recommended drink but I decided to go for latte that is in a bigger cup.",
#   'time': 1749384950,
#   'translated': False},
#  {'author_name': 'Gereon Ninety-Nine',
#   'author_url': 'https://www.google.com/maps/contrib/100978336738568137569/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKQlcy2iR63SxDrEwd7972nFsvLI1lIO2BPw_xjgQ1m547vKg=s128-c0x00000000-cc-rp-mo-ba5',
#   'rating': 5,
#   'relative_time_description': '2 months ago',
#   'text': 'Every time I visit Singapore, I always come to this fantastic cafe. It’s a lovely cool heritage spot. Evolving menu of western brunch faves and quality baked goods. The coffee is probably the best part, whether hot or cold, espresso, filter, or brew. Great spot to while away some time.',
#   'time': 1752295910,
#   'translated': False}]

# %% [markdown]
# ### full test scripts

# %%
"""Test script to query one neighborhood"""

from src.data.query import CafeQuery
import pandas as pd
from datetime import datetime

def test_single_neighborhood():
    # Initialize the query class
    print("Initializing cafe query...")
    cafe_query = CafeQuery()
    
    # Pick one neighborhood to test (Holland Village)
    test_neighborhood = {
        'center': [1.3120885, 103.7958535],
        'radius': 1200,
        'neighborhood_name': 'katong',
        'region': 'west'
    }
    
    print(f"\nTesting with {test_neighborhood['neighborhood_name']}...")
    print(f"Center: {test_neighborhood['center']}")
    print(f"Radius: {test_neighborhood['radius']}m")
    
    # Collect cafes
    try:
        df = cafe_query.collect_cafes(test_neighborhood)
        
        if not df.empty:
            print(f"\n✅ Success! Found {len(df)} cafes")
            print("\nSample data:")
            print(df[['name', 'rating', 'user_ratings_total']].head())
            
            # Save test results
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            output_path = f'data/test_holland_village_{timestamp}.parquet'
            df.to_parquet(output_path)
            print(f"\nData saved to: {output_path}")
            
            # Show summary
            print("\nSummary:")
            print(f"- Total cafes: {len(df)}")
            print(f"- Avg rating: {df['rating'].mean():.2f}")
            print(f"- Has price info: {df['price_level'].notna().sum()}")
            
        else:
            print("❌ No cafes found")
            
    except Exception as e:
        print(f"❌ Error: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    test_single_neighborhood()
# Out:
# Initializing cafe query...
# Client initialized and cafe reviews for 12 neighborhoods will be extracted
#
# Testing with katong...
# Center: [1.3120885, 103.7958535]
# Radius: 1200m
#
# ✅ Success! Found 60 cafes
#
# Sample data:
#                                   name  rating  user_ratings_total
# 0                      The Daily Scoop     4.3               857.0
# 1  Tai Cheong Bakery (Holland Village)     4.1               877.0
# 2       Chang Cheng Mee Wah Coffeeshop     3.8               195.0
# 3            Attap House - Buona Vista     3.4                98.0
# 4                            Fun Toast     3.3               142.0
#
# Data saved to: data/test_holland_village_20250929_234839.parquet
#
# Summary:
# - Total cafes: 60
# - Avg rating: 4.13
# - Has price info: 14

# %%
df_katong = pd.read_parquet('data/test_katong_20250929_234839.parquet')
df_katong
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 1.3105313, 'lng': 103.796...
# 1          OPERATIONAL  {'location': {'lat': 1.3106268, 'lng': 103.794...
# 2          OPERATIONAL  {'location': {'lat': 1.3072268, 'lng': 103.793...
# 3          OPERATIONAL  {'location': {'lat': 1.3056275, 'lng': 103.791...
# 4          OPERATIONAL  {'location': {'lat': 1.307062, 'lng': 103.7880...
# 5          OPERATIONAL  {'location': {'lat': 1.3070419, 'lng': 103.787...
# 6          OPERATIONAL  {'location': {'lat': 1.3032732, 'lng': 103.791...
# 7          OPERATIONAL  {'location': {'lat': 1.3023818, 'lng': 103.792...
# 8          OPERATIONAL  {'location': {'lat': 1.3021485, 'lng': 103.793...
# 9          OPERATIONAL  {'location': {'lat': 1.305518, 'lng': 103.7877...
# 10         OPERATIONAL  {'location': {'lat': 1.3105213, 'lng': 103.796...
# 11         OPERATIONAL  {'location': {'lat': 1.31178, 'lng': 103.79525...
# 12         OPERATIONAL  {'location': {'lat': 1.3114616, 'lng': 103.796...
# 13         OPERATIONAL  {'location': {'lat': 1.3116993, 'lng': 103.796...
# 14         OPERATIONAL  {'location': {'lat': 1.3117282, 'lng': 103.794...
# 15         OPERATIONAL  {'location': {'lat': 1.3112443, 'lng': 103.795...
# 16         OPERATIONAL  {'location': {'lat': 1.3110088, 'lng': 103.795...
# 17         OPERATIONAL  {'location': {'lat': 1.3112134, 'lng': 103.795...
# 18  CLOSED_TEMPORARILY  {'location': {'lat': 1.311102, 'lng': 103.7949...
# 19         OPERATIONAL  {'location': {'lat': 1.311102, 'lng': 103.7949...
# 20         OPERATIONAL  {'location': {'lat': 1.3121245, 'lng': 103.797...
# 21         OPERATIONAL  {'location': {'lat': 1.311087, 'lng': 103.7949...
# 22         OPERATIONAL  {'location': {'lat': 1.3106807, 'lng': 103.795...
# 23         OPERATIONAL  {'location': {'lat': 1.3106807, 'lng': 103.795...
# 24         OPERATIONAL  {'location': {'lat': 1.3106612, 'lng': 103.796...
# 25         OPERATIONAL  {'location': {'lat': 1.3105766, 'lng': 103.796...
# 26         OPERATIONAL  {'location': {'lat': 1.3120969, 'lng': 103.794...
# 27         OPERATIONAL  {'location': {'lat': 1.310647, 'lng': 103.7964...
# 28         OPERATIONAL  {'location': {'lat': 1.3106843, 'lng': 103.794...
# 29         OPERATIONAL  {'location': {'lat': 1.3113204, 'lng': 103.794...
# 30         OPERATIONAL  {'location': {'lat': 1.3120066, 'lng': 103.793...
# 31         OPERATIONAL  {'location': {'lat': 1.3114533, 'lng': 103.794...
# 32         OPERATIONAL  {'location': {'lat': 1.3103457, 'lng': 103.795...
# 33         OPERATIONAL  {'location': {'lat': 1.3115721, 'lng': 103.793...
# 34         OPERATIONAL  {'location': {'lat': 1.3112574, 'lng': 103.794...
# 35         OPERATIONAL  {'location': {'lat': 1.3103955, 'lng': 103.794...
# 36         OPERATIONAL  {'location': {'lat': 1.310262, 'lng': 103.7949...
# 37         OPERATIONAL  {'location': {'lat': 1.3106534, 'lng': 103.794...
# 38         OPERATIONAL  {'location': {'lat': 1.3114782, 'lng': 103.793...
# 39         OPERATIONAL  {'location': {'lat': 1.3114401, 'lng': 103.793...
# 40         OPERATIONAL  {'location': {'lat': 1.3088886, 'lng': 103.792...
# 41         OPERATIONAL  {'location': {'lat': 1.3088172, 'lng': 103.792...
# 42         OPERATIONAL  {'location': {'lat': 1.3075752, 'lng': 103.795...
# 43         OPERATIONAL  {'location': {'lat': 1.3087274, 'lng': 103.792...
# 44         OPERATIONAL  {'location': {'lat': 1.3083956, 'lng': 103.792...
# 45         OPERATIONAL  {'location': {'lat': 1.3086547, 'lng': 103.792...
# 46         OPERATIONAL  {'location': {'lat': 1.3081341, 'lng': 103.792...
# 47         OPERATIONAL  {'location': {'lat': 1.3071882, 'lng': 103.795...
# 48         OPERATIONAL  {'location': {'lat': 1.308167, 'lng': 103.7927...
# 49         OPERATIONAL  {'location': {'lat': 1.308167, 'lng': 103.7927...
# 50         OPERATIONAL  {'location': {'lat': 1.3071143, 'lng': 103.795...
# 51         OPERATIONAL  {'location': {'lat': 1.3071143, 'lng': 103.795...
# 52         OPERATIONAL  {'location': {'lat': 1.3070573, 'lng': 103.797...
# 53         OPERATIONAL  {'location': {'lat': 1.3068684, 'lng': 103.797...
# 54         OPERATIONAL  {'location': {'lat': 1.3071989, 'lng': 103.793...
# 55         OPERATIONAL  {'location': {'lat': 1.3071989, 'lng': 103.793...
# 56         OPERATIONAL  {'location': {'lat': 1.3077089, 'lng': 103.792...
# 57         OPERATIONAL  {'location': {'lat': 1.3077564, 'lng': 103.792...
# 58         OPERATIONAL  {'location': {'lat': 1.3076924, 'lng': 103.792...
# 59         OPERATIONAL  {'location': {'lat': 1.3071557, 'lng': 103.793...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 22  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 23  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 24  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 25  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 26  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 27  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 28  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 29  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 30  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 31  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 32  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 33  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 34  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 35  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 36  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 37  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 38  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 39  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 40  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 41  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 42  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 43  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 44  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 45  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 46  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 47  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 48  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 49  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 50  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 51  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 52  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 53  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 54  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 55  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 56  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 57  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 58  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 59  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...
# 22  https://maps.gstatic.com/mapfiles/place_api/ic...
# 23  https://maps.gstatic.com/mapfiles/place_api/ic...
# 24  https://maps.gstatic.com/mapfiles/place_api/ic...
# 25  https://maps.gstatic.com/mapfiles/place_api/ic...
# 26  https://maps.gstatic.com/mapfiles/place_api/ic...
# 27  https://maps.gstatic.com/mapfiles/place_api/ic...
# 28  https://maps.gstatic.com/mapfiles/place_api/ic...
# 29  https://maps.gstatic.com/mapfiles/place_api/ic...
# 30  https://maps.gstatic.com/mapfiles/place_api/ic...
# 31  https://maps.gstatic.com/mapfiles/place_api/ic...
# 32  https://maps.gstatic.com/mapfiles/place_api/ic...
# 33  https://maps.gstatic.com/mapfiles/place_api/ic...
# 34  https://maps.gstatic.com/mapfiles/place_api/ic...
# 35  https://maps.gstatic.com/mapfiles/place_api/ic...
# 36  https://maps.gstatic.com/mapfiles/place_api/ic...
# 37  https://maps.gstatic.com/mapfiles/place_api/ic...
# 38  https://maps.gstatic.com/mapfiles/place_api/ic...
# 39  https://maps.gstatic.com/mapfiles/place_api/ic...
# 40  https://maps.gstatic.com/mapfiles/place_api/ic...
# 41  https://maps.gstatic.com/mapfiles/place_api/ic...
# 42  https://maps.gstatic.com/mapfiles/place_api/ic...
# 43  https://maps.gstatic.com/mapfiles/place_api/ic...
# 44  https://maps.gstatic.com/mapfiles/place_api/ic...
# 45  https://maps.gstatic.com/mapfiles/place_api/ic...
# 46  https://maps.gstatic.com/mapfiles/place_api/ic...
# 47  https://maps.gstatic.com/mapfiles/place_api/ic...
# 48  https://maps.gstatic.com/mapfiles/place_api/ic...
# 49  https://maps.gstatic.com/mapfiles/place_api/ic...
# 50  https://maps.gstatic.com/mapfiles/place_api/ic...
# 51  https://maps.gstatic.com/mapfiles/place_api/ic...
# 52  https://maps.gstatic.com/mapfiles/place_api/ic...
# 53  https://maps.gstatic.com/mapfiles/place_api/ic...
# 54  https://maps.gstatic.com/mapfiles/place_api/ic...
# 55  https://maps.gstatic.com/mapfiles/place_api/ic...
# 56  https://maps.gstatic.com/mapfiles/place_api/ic...
# 57  https://maps.gstatic.com/mapfiles/place_api/ic...
# 58  https://maps.gstatic.com/mapfiles/place_api/ic...
# 59  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                  name        opening_hours  \
# 0                                     The Daily Scoop  {'open_now': False}
# 1                 Tai Cheong Bakery (Holland Village)  {'open_now': False}
# 2                      Chang Cheng Mee Wah Coffeeshop   {'open_now': True}
# 3                           Attap House - Buona Vista  {'open_now': False}
# 4                                           Fun Toast  {'open_now': False}
# 5                                      Caffè Affogato  {'open_now': False}
# 6                              Bodacious bar & bistro  {'open_now': False}
# 7                                  Nanyang Old Coffee  {'open_now': False}
# 8                          Little Big Coffee Roasters  {'open_now': False}
# 9                            Starbucks Rochester Park  {'open_now': False}
# 10             Da Paolo Gastronomia - Holland Village  {'open_now': False}
# 11                       Craftsmen Coffee (Holland V)  {'open_now': False}
# 12               % Arabica Singapore Chip Bee Gardens  {'open_now': False}
# 13  Baker & Cook - Chip Bee Gardens - Mastercard P...  {'open_now': False}
# 14                                The Pocha Singapore   {'open_now': True}
# 15                                   Wan Jin Yuan 万金园  {'open_now': False}
# 16   Little Farms Table, Holland Village (Restaurant)  {'open_now': False}
# 17                         Holland V Coffee and Drink  {'open_now': False}
# 18                                       Ya Zhou Cafe                 None
# 19                                     Shan Quan Cafe  {'open_now': False}
# 20               Keong Saik Bakery @ Chip Bee Gardens  {'open_now': False}
# 21  Miniwok - Holland Village Market and Food Cent...   {'open_now': True}
# 22                              MAVRX Holland Village  {'open_now': False}
# 23                                   Frankie & Fern's  {'open_now': False}
# 24                                             Cafe O  {'open_now': False}
# 25                          Dunkin' Raffles Holland V  {'open_now': False}
# 26                                             Lola's  {'open_now': False}
# 27                                 Tiong Bahru Bakery  {'open_now': False}
# 28  Rasoi- The Indian Kitchen,(PEPPER CASTLE) Holl...                 None
# 29                    CAFFE BEVIAMO - Holland Village  {'open_now': False}
# 30  Surrey Hills Grocer - One Holland Village (Pet...  {'open_now': False}
# 31                                  cocobella lifebar  {'open_now': False}
# 32                                     Elixir Esports   {'open_now': True}
# 33                                          Watermill   {'open_now': True}
# 34                      Starbucks One Holland Village  {'open_now': False}
# 35                               flora by face bistro  {'open_now': False}
# 36                Two Men Bagel House Holland Village  {'open_now': False}
# 37                Awfully Chocolate (Holland Village)  {'open_now': False}
# 38                    TSUJIRI Premium Holland Village  {'open_now': False}
# 39                                     Plain Meredith  {'open_now': False}
# 40                              46CTK@Seafood Pte Ltd  {'open_now': False}
# 41                Chef Li Supreme Ramen Xiao Long Bao  {'open_now': False}
# 42                                      That Place.SG  {'open_now': False}
# 43   Holland drive Hainanese Chicken rice herbal soup  {'open_now': False}
# 44                               Fatty Cat Curry Rice  {'open_now': False}
# 45                          43 Holland Popiah & Rojak                 None
# 46                                       Lau Tong Kee  {'open_now': False}
# 47                             6 @ Holland Coffeeshop  {'open_now': False}
# 48                                          旺来杂菜饭、番薯粥                 None
# 49                               Kim Hua Coffee Stall  {'open_now': False}
# 50                   Seng Huat Coffee House @ Holland  {'open_now': False}
# 51                                 The Soya Bean Shop  {'open_now': False}
# 52                     Weyoung Japanese Korean Bentos                 None
# 53                          Aces League 31 Food Court                 None
# 54                 Traditional Handmade Mee Hoon Kueh  {'open_now': False}
# 55                             Chef Wei HK Cheong Fun  {'open_now': False}
# 56                     Jia Jia Peanut Pancake (佳佳面煎粿）  {'open_now': False}
# 57  Man Xiang Tradtional Roasted Delight 满香传统烧腊 (4...                 None
# 58                               S-11 HL43 Food House   {'open_now': True}
# 59             Wang wang lor mee and fish soup 旺旺卤面鱼汤                 None
#
#                                                photos  \
# 0   [{'height': 3000, 'html_attributions': ['<a hr...
# 1   [{'height': 1200, 'html_attributions': ['<a hr...
# 2   [{'height': 2304, 'html_attributions': ['<a hr...
# 3   [{'height': 3840, 'html_attributions': ['<a hr...
# 4   [{'height': 3024, 'html_attributions': ['<a hr...
# 5   [{'height': 2268, 'html_attributions': ['<a hr...
# 6   [{'height': 2592, 'html_attributions': ['<a hr...
# 7   [{'height': 4000, 'html_attributions': ['<a hr...
# 8   [{'height': 2921, 'html_attributions': ['<a hr...
# 9   [{'height': 2160, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11  [{'height': 4032, 'html_attributions': ['<a hr...
# 12  [{'height': 1452, 'html_attributions': ['<a hr...
# 13  [{'height': 3670, 'html_attributions': ['<a hr...
# 14  [{'height': 2000, 'html_attributions': ['<a hr...
# 15  [{'height': 3024, 'html_attributions': ['<a hr...
# 16  [{'height': 4387, 'html_attributions': ['<a hr...
# 17  [{'height': 4032, 'html_attributions': ['<a hr...
# 18                                               None
# 19  [{'height': 3024, 'html_attributions': ['<a hr...
# 20  [{'height': 5712, 'html_attributions': ['<a hr...
# 21                                               None
# 22  [{'height': 1067, 'html_attributions': ['<a hr...
# 23  [{'height': 2268, 'html_attributions': ['<a hr...
# 24  [{'height': 5304, 'html_attributions': ['<a hr...
# 25  [{'height': 4032, 'html_attributions': ['<a hr...
# 26  [{'height': 2268, 'html_attributions': ['<a hr...
# 27  [{'height': 2252, 'html_attributions': ['<a hr...
# 28                                               None
# 29  [{'height': 4032, 'html_attributions': ['<a hr...
# 30  [{'height': 899, 'html_attributions': ['<a hre...
# 31  [{'height': 2048, 'html_attributions': ['<a hr...
# 32  [{'height': 5464, 'html_attributions': ['<a hr...
# 33                                               None
# 34  [{'height': 2992, 'html_attributions': ['<a hr...
# 35  [{'height': 3000, 'html_attributions': ['<a hr...
# 36  [{'height': 853, 'html_attributions': ['<a hre...
# 37  [{'height': 1679, 'html_attributions': ['<a hr...
# 38  [{'height': 1536, 'html_attributions': ['<a hr...
# 39  [{'height': 2400, 'html_attributions': ['<a hr...
# 40  [{'height': 4032, 'html_attributions': ['<a hr...
# 41  [{'height': 3136, 'html_attributions': ['<a hr...
# 42  [{'height': 4032, 'html_attributions': ['<a hr...
# 43  [{'height': 2977, 'html_attributions': ['<a hr...
# 44  [{'height': 900, 'html_attributions': ['<a hre...
# 45  [{'height': 4032, 'html_attributions': ['<a hr...
# 46  [{'height': 2988, 'html_attributions': ['<a hr...
# 47  [{'height': 3786, 'html_attributions': ['<a hr...
# 48  [{'height': 3378, 'html_attributions': ['<a hr...
# 49  [{'height': 3024, 'html_attributions': ['<a hr...
# 50  [{'height': 3599, 'html_attributions': ['<a hr...
# 51  [{'height': 4284, 'html_attributions': ['<a hr...
# 52  [{'height': 4080, 'html_attributions': ['<a hr...
# 53  [{'height': 3024, 'html_attributions': ['<a hr...
# 54  [{'height': 4032, 'html_attributions': ['<a hr...
# 55  [{'height': 3024, 'html_attributions': ['<a hr...
# 56  [{'height': 2448, 'html_attributions': ['<a hr...
# 57                                               None
# 58  [{'height': 2268, 'html_attributions': ['<a hr...
# 59  [{'height': 1536, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJSf_v4moa2jERfL_gQn4nX7k
# 1   ChIJ_wM9jJEZ2jERUe-5RzyA24w
# 2   ChIJH3Fr7UEa2jERuwMcr9cFUvw
# 3   ChIJOxwfQEUa2jERPpaLevc5gyo
# 4   ChIJp0JVlEIa2jERu8As-QXcW1Q
# 5   ChIJAYFXlgYa2jERzXR4KdyTEM4
# 6   ChIJ225l_0Ma2jERCNNkY0Fmqr0
# 7   ChIJITFuHkQa2jERJRPve-kqGKU
# 8   ChIJYWEEl0Ya2jERSazPjSyLxe4
# 9   ChIJTyS910Ia2jERCTho_ldH97E
# 10  ChIJF1q7G2sa2jERq-Qz_QEGmig
# 11  ChIJAcJ9_Vsb2jERoJlYydSCUOc
# 12  ChIJ15EvGAwb2jERRGPpb9vrbGs
# 13  ChIJMZjFQmsa2jERiWTTpzE9Ui8
# 14  ChIJgcLm1Wwb2jERC_LK3E52tMI
# 15  ChIJwaD9MAAb2jER9t_T-d5zLYA
# 16  ChIJk5LC3T8b2jERJCn11hpi1tI
# 17  ChIJGc8TpWsa2jER9oU4h8PSGoo
# 18  ChIJGc8TpWsa2jER3bGPsnsctIc
# 19  ChIJGc8TpWsa2jERpyT-n6SvDXc
# 20  ChIJt_Eg_9kb2jER9IMW9y95nbc
# 21  ChIJk2JTFTEb2jERfdOoQGw7C7s
# 22  ChIJqWN_nYIb2jERGf-bDY1IV0w
# 23  ChIJm-PDnAIb2jEROQfXnfMevIA
# 24  ChIJtZp_A2sa2jERQi_UpcVg-so
# 25  ChIJu_4GwFsb2jERY9Yssgkh6VQ
# 26  ChIJ5RaT_S8b2jERLkF7fluZ-RI
# 27  ChIJp18pzAcb2jERHmqZmnGRaag
# 28  ChIJWddqeAAb2jERnv4AD3WGR7w
# 29  ChIJt-l_PgAb2jERDFeQjgoQ9ro
# 30  ChIJadntJQAb2jERr18tHt0cyEg
# 31  ChIJH7FlYgAb2jERyEPWsW6Tfak
# 32  ChIJA8gdKSQb2jER1URTCwqhiNo
# 33  ChIJhQj5SgAb2jERvZxLIwP1GYU
# 34  ChIJXV4K9bgb2jERnyYM2k6rii4
# 35  ChIJwfFq7lkZ2jERL0JpzcRWFHE
# 36  ChIJcxZynE8b2jER4MDmsMBPOnc
# 37  ChIJH1-5IwAb2jERztARmXrwd7Q
# 38  ChIJO_L0YgAb2jERJ5keFiHnjNc
# 39  ChIJe-fz2Cgb2jERKTZiBgSNN_E
# 40  ChIJOdYvQlgb2jERaOGZ0DGvat8
# 41  ChIJv70bW4Ab2jERBOCK37a-gFo
# 42  ChIJnz3qAQk92jERhwM_H3eMEf4
# 43  ChIJsa4nIWoa2jERBw6V20F4qSY
# 44  ChIJc67MRwAb2jERpXrqMCJjqsg
# 45  ChIJ0TPVE5kb2jERi3YMcsoZ9wk
# 46  ChIJi_P4HZob2jERD-f12xTkNQo
# 47  ChIJO7P4d80b2jER1pY36Y1e4xE
# 48  ChIJcZFZTAAb2jERknUIovSfFKU
# 49  ChIJ7SUpBGoa2jERlqh5Z2aIh3I
# 50  ChIJ09LcuqIb2jERTVnm0xfYijY
# 51  ChIJrfgxPQAb2jERLrWt05seBBs
# 52  ChIJs-hD7Zkb2jERlrRJ_mbOzLU
# 53  ChIJdcdzao8b2jERBlUnVnBnY14
# 54  ChIJS3Ep0RUb2jERvna9dvr5GH4
# 55  ChIJ2_32aEcb2jER-2N5SS_DwAI
# 56  ChIJaa_FxzAb2jER9bK7_zEqKUk
# 57  ChIJv3eHNAAb2jERchvHX38S3Dw
# 58  ChIJczbj-UEa2jERZjT8A7dyNq0
# 59  ChIJIXs4QgAb2jERq4EeMT1s9Bs
#
#                                             plus_code  rating  \
# 0   {'compound_code': '8Q6W+6F Singapore', 'global...     4.3
# 1   {'compound_code': '8Q6V+7X Singapore', 'global...     4.1
# 2   {'compound_code': '8Q4V+V9 Singapore', 'global...     3.8
# 3   {'compound_code': '8Q4R+7J Singapore', 'global...     3.4
# 4   {'compound_code': '8Q4Q+R6 Singapore', 'global...     3.3
# 5   {'compound_code': '8Q4Q+R4 Singapore', 'global...     4.1
# 6   {'compound_code': '8Q3R+8P Singapore', 'global...     4.1
# 7   {'compound_code': '8Q2V+X2 Singapore', 'global...     3.9
# 8   {'compound_code': '8Q2V+V6 Singapore', 'global...     4.7
# 9   {'compound_code': '8Q4Q+64 Singapore', 'global...     4.3
# 10  {'compound_code': '8Q6W+6F Singapore', 'global...     4.0
# 11  {'compound_code': '8Q6W+P4 Singapore', 'global...     4.3
# 12  {'compound_code': '8Q6W+HJ Singapore', 'global...     3.9
# 13  {'compound_code': '8Q6W+MP Singapore', 'global...     4.0
# 14  {'compound_code': '8Q6V+MW Singapore', 'global...     4.6
# 15  {'compound_code': '8Q6W+F2 Singapore', 'global...     4.1
# 16  {'compound_code': '8Q6W+C4 Singapore', 'global...     4.4
# 17  {'compound_code': '8Q6W+F2 Singapore', 'global...     3.9
# 18  {'compound_code': '8Q6V+CX Singapore', 'global...     NaN
# 19  {'compound_code': '8Q6V+CX Singapore', 'global...     4.0
# 20  {'compound_code': '8Q6W+RV Singapore', 'global...     4.2
# 21  {'compound_code': '8Q6V+CX Singapore', 'global...     5.0
# 22  {'compound_code': '8Q6W+76 Singapore', 'global...     4.3
# 23  {'compound_code': '8Q6W+76 Singapore', 'global...     4.5
# 24  {'compound_code': '8Q6W+7H Singapore', 'global...     3.2
# 25  {'compound_code': '8Q6W+6C Singapore', 'global...     4.3
# 26  {'compound_code': '8Q6V+RP Singapore', 'global...     4.4
# 27  {'compound_code': '8Q6W+7H Singapore', 'global...     4.3
# 28  {'compound_code': '8Q6V+7X Singapore', 'global...     NaN
# 29  {'compound_code': '8Q6V+GM Singapore', 'global...     4.2
# 30  {'compound_code': '8Q6V+RH Singapore', 'global...     4.4
# 31  {'compound_code': '8Q6V+HJ Singapore', 'global...     4.3
# 32  {'compound_code': '8Q6W+42 Singapore', 'global...     5.0
# 33  {'compound_code': '8Q6V+JH Singapore', 'global...     NaN
# 34  {'compound_code': '8Q6V+GJ Singapore', 'global...     3.4
# 35  {'compound_code': '8Q6V+5W Singapore', 'global...     5.0
# 36  {'compound_code': '8Q6V+4X Singapore', 'global...     4.3
# 37  {'compound_code': '8Q6V+7P Singapore', 'global...     4.5
# 38  {'compound_code': '8Q6V+HF Singapore', 'global...     3.8
# 39  {'compound_code': '8Q6V+HF Singapore', 'global...     4.7
# 40  {'compound_code': '8Q5V+H5 Singapore', 'global...     4.1
# 41  {'compound_code': '8Q5V+G4 Singapore', 'global...     4.6
# 42  {'compound_code': '8Q5W+24 Singapore', 'global...     5.0
# 43  {'compound_code': '8Q5V+F3 Singapore', 'global...     4.4
# 44  {'compound_code': '8Q5V+95 Singapore', 'global...     4.1
# 45  {'compound_code': '8Q5R+FX Singapore', 'global...     3.3
# 46  {'compound_code': '8Q5V+75 Singapore', 'global...     3.5
# 47  {'compound_code': '8Q4W+V4 Singapore', 'global...     4.1
# 48  {'compound_code': '8Q5V+74 Singapore', 'global...     5.0
# 49  {'compound_code': '8Q5V+74 Singapore', 'global...     4.0
# 50  {'compound_code': '8Q4W+R5 Singapore', 'global...     NaN
# 51  {'compound_code': '8Q4W+R5 Singapore', 'global...     4.6
# 52  {'compound_code': '8Q4W+RR Singapore', 'global...     1.5
# 53  {'compound_code': '8Q4W+PW Singapore', 'global...     3.7
# 54  {'compound_code': '8Q4V+V9 Singapore', 'global...     2.4
# 55  {'compound_code': '8Q4V+V9 Singapore', 'global...     4.4
# 56  {'compound_code': '8Q5V+32 Singapore', 'global...     5.0
# 57  {'compound_code': '8Q5V+42 Singapore', 'global...     5.0
# 58  {'compound_code': '8Q5V+32 Singapore', 'global...     3.6
# 59  {'compound_code': '8Q4V+V9 Singapore', 'global...     NaN
#
#                       reference   scope  \
# 0   ChIJSf_v4moa2jERfL_gQn4nX7k  GOOGLE
# 1   ChIJ_wM9jJEZ2jERUe-5RzyA24w  GOOGLE
# 2   ChIJH3Fr7UEa2jERuwMcr9cFUvw  GOOGLE
# 3   ChIJOxwfQEUa2jERPpaLevc5gyo  GOOGLE
# 4   ChIJp0JVlEIa2jERu8As-QXcW1Q  GOOGLE
# 5   ChIJAYFXlgYa2jERzXR4KdyTEM4  GOOGLE
# 6   ChIJ225l_0Ma2jERCNNkY0Fmqr0  GOOGLE
# 7   ChIJITFuHkQa2jERJRPve-kqGKU  GOOGLE
# 8   ChIJYWEEl0Ya2jERSazPjSyLxe4  GOOGLE
# 9   ChIJTyS910Ia2jERCTho_ldH97E  GOOGLE
# 10  ChIJF1q7G2sa2jERq-Qz_QEGmig  GOOGLE
# 11  ChIJAcJ9_Vsb2jERoJlYydSCUOc  GOOGLE
# 12  ChIJ15EvGAwb2jERRGPpb9vrbGs  GOOGLE
# 13  ChIJMZjFQmsa2jERiWTTpzE9Ui8  GOOGLE
# 14  ChIJgcLm1Wwb2jERC_LK3E52tMI  GOOGLE
# 15  ChIJwaD9MAAb2jER9t_T-d5zLYA  GOOGLE
# 16  ChIJk5LC3T8b2jERJCn11hpi1tI  GOOGLE
# 17  ChIJGc8TpWsa2jER9oU4h8PSGoo  GOOGLE
# 18  ChIJGc8TpWsa2jER3bGPsnsctIc  GOOGLE
# 19  ChIJGc8TpWsa2jERpyT-n6SvDXc  GOOGLE
# 20  ChIJt_Eg_9kb2jER9IMW9y95nbc  GOOGLE
# 21  ChIJk2JTFTEb2jERfdOoQGw7C7s  GOOGLE
# 22  ChIJqWN_nYIb2jERGf-bDY1IV0w  GOOGLE
# 23  ChIJm-PDnAIb2jEROQfXnfMevIA  GOOGLE
# 24  ChIJtZp_A2sa2jERQi_UpcVg-so  GOOGLE
# 25  ChIJu_4GwFsb2jERY9Yssgkh6VQ  GOOGLE
# 26  ChIJ5RaT_S8b2jERLkF7fluZ-RI  GOOGLE
# 27  ChIJp18pzAcb2jERHmqZmnGRaag  GOOGLE
# 28  ChIJWddqeAAb2jERnv4AD3WGR7w  GOOGLE
# 29  ChIJt-l_PgAb2jERDFeQjgoQ9ro  GOOGLE
# 30  ChIJadntJQAb2jERr18tHt0cyEg  GOOGLE
# 31  ChIJH7FlYgAb2jERyEPWsW6Tfak  GOOGLE
# 32  ChIJA8gdKSQb2jER1URTCwqhiNo  GOOGLE
# 33  ChIJhQj5SgAb2jERvZxLIwP1GYU  GOOGLE
# 34  ChIJXV4K9bgb2jERnyYM2k6rii4  GOOGLE
# 35  ChIJwfFq7lkZ2jERL0JpzcRWFHE  GOOGLE
# 36  ChIJcxZynE8b2jER4MDmsMBPOnc  GOOGLE
# 37  ChIJH1-5IwAb2jERztARmXrwd7Q  GOOGLE
# 38  ChIJO_L0YgAb2jERJ5keFiHnjNc  GOOGLE
# 39  ChIJe-fz2Cgb2jERKTZiBgSNN_E  GOOGLE
# 40  ChIJOdYvQlgb2jERaOGZ0DGvat8  GOOGLE
# 41  ChIJv70bW4Ab2jERBOCK37a-gFo  GOOGLE
# 42  ChIJnz3qAQk92jERhwM_H3eMEf4  GOOGLE
# 43  ChIJsa4nIWoa2jERBw6V20F4qSY  GOOGLE
# 44  ChIJc67MRwAb2jERpXrqMCJjqsg  GOOGLE
# 45  ChIJ0TPVE5kb2jERi3YMcsoZ9wk  GOOGLE
# 46  ChIJi_P4HZob2jERD-f12xTkNQo  GOOGLE
# 47  ChIJO7P4d80b2jER1pY36Y1e4xE  GOOGLE
# 48  ChIJcZFZTAAb2jERknUIovSfFKU  GOOGLE
# 49  ChIJ7SUpBGoa2jERlqh5Z2aIh3I  GOOGLE
# 50  ChIJ09LcuqIb2jERTVnm0xfYijY  GOOGLE
# 51  ChIJrfgxPQAb2jERLrWt05seBBs  GOOGLE
# 52  ChIJs-hD7Zkb2jERlrRJ_mbOzLU  GOOGLE
# 53  ChIJdcdzao8b2jERBlUnVnBnY14  GOOGLE
# 54  ChIJS3Ep0RUb2jERvna9dvr5GH4  GOOGLE
# 55  ChIJ2_32aEcb2jER-2N5SS_DwAI  GOOGLE
# 56  ChIJaa_FxzAb2jER9bK7_zEqKUk  GOOGLE
# 57  ChIJv3eHNAAb2jERchvHX38S3Dw  GOOGLE
# 58  ChIJczbj-UEa2jERZjT8A7dyNq0  GOOGLE
# 59  ChIJIXs4QgAb2jERq4EeMT1s9Bs  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [cafe, store, food, point_of_interest, establi...               857.0
# 1   [cafe, bakery, store, food, point_of_interest,...               877.0
# 2   [cafe, store, food, point_of_interest, establi...               195.0
# 3   [restaurant, cafe, food, point_of_interest, es...                98.0
# 4   [cafe, store, food, point_of_interest, establi...               142.0
# 5   [cafe, store, food, point_of_interest, establi...               397.0
# 6   [cafe, restaurant, food, point_of_interest, es...               368.0
# 7      [cafe, food, point_of_interest, establishment]                70.0
# 8      [cafe, food, point_of_interest, establishment]               193.0
# 9   [cafe, store, food, point_of_interest, establi...               874.0
# 10  [cafe, grocery_or_supermarket, store, restaura...               384.0
# 11  [cafe, store, food, point_of_interest, establi...              1329.0
# 12  [cafe, store, restaurant, food, point_of_inter...               484.0
# 13  [bakery, cafe, store, food, point_of_interest,...               605.0
# 14  [cafe, restaurant, food, point_of_interest, es...               691.0
# 15  [cafe, store, food, point_of_interest, establi...                23.0
# 16  [restaurant, cafe, food, point_of_interest, es...               335.0
# 17     [cafe, food, point_of_interest, establishment]                12.0
# 18     [cafe, food, point_of_interest, establishment]                 NaN
# 19     [cafe, food, point_of_interest, establishment]                16.0
# 20     [cafe, food, point_of_interest, establishment]               287.0
# 21  [cafe, store, food, point_of_interest, establi...                 1.0
# 22  [cafe, store, food, point_of_interest, establi...                48.0
# 23  [cafe, restaurant, food, point_of_interest, es...               623.0
# 24  [cafe, store, food, point_of_interest, establi...               337.0
# 25  [cafe, bakery, store, food, point_of_interest,...                26.0
# 26     [cafe, food, point_of_interest, establishment]               600.0
# 27  [cafe, meal_takeaway, bakery, store, restauran...               856.0
# 28  [cafe, store, food, point_of_interest, establi...                 NaN
# 29  [restaurant, cafe, food, point_of_interest, es...               175.0
# 30  [cafe, grocery_or_supermarket, store, restaura...               763.0
# 31     [cafe, food, point_of_interest, establishment]               135.0
# 32  [cafe, restaurant, food, point_of_interest, es...               533.0
# 33     [cafe, food, point_of_interest, establishment]                 NaN
# 34  [cafe, store, food, point_of_interest, establi...                57.0
# 35  [spa, cafe, beauty_salon, food, point_of_inter...                20.0
# 36  [cafe, bakery, store, food, point_of_interest,...               463.0
# 37     [cafe, food, point_of_interest, establishment]               124.0
# 38  [cafe, restaurant, food, point_of_interest, es...               322.0
# 39     [cafe, food, point_of_interest, establishment]               858.0
# 40  [cafe, point_of_interest, food, store, establi...                17.0
# 41  [cafe, point_of_interest, food, store, establi...                31.0
# 42     [cafe, point_of_interest, food, establishment]                 4.0
# 43  [cafe, point_of_interest, food, store, establi...                 7.0
# 44  [cafe, point_of_interest, food, store, establi...                22.0
# 45  [cafe, point_of_interest, food, store, establi...                 3.0
# 46     [cafe, point_of_interest, food, establishment]                 2.0
# 47  [cafe, point_of_interest, food, store, establi...               152.0
# 48  [cafe, point_of_interest, food, store, establi...                 5.0
# 49  [cafe, point_of_interest, food, store, establi...                 1.0
# 50  [cafe, point_of_interest, food, store, establi...                 NaN
# 51  [cafe, point_of_interest, food, store, establi...                17.0
# 52  [cafe, point_of_interest, food, store, establi...                 4.0
# 53  [cafe, point_of_interest, food, store, establi...                27.0
# 54  [cafe, point_of_interest, food, store, establi...                22.0
# 55  [cafe, restaurant, point_of_interest, food, st...               252.0
# 56  [cafe, point_of_interest, food, store, establi...                 6.0
# 57  [cafe, point_of_interest, food, store, establi...                 1.0
# 58  [cafe, point_of_interest, food, store, establi...               275.0
# 59  [cafe, point_of_interest, food, store, establi...                 NaN
#
#                                              vicinity  price_level  \
# 0                  118 Holland Avenue, #02-04 Raffles          NaN
# 1                                     31 Lorong Liput          2.0
# 2   Blk 40 Holland Drive #01-39, Block 40 Holland ...          1.0
# 3   9 North Buona Vista Drive, #01-17 The Metropol...          NaN
# 4       1 Vista Exchange Green, #02-03 The Star Vista          NaN
# 5       1 Vista Exchange Green, #01-02 The Star Vista          2.0
# 6                          70 Biopolis Street, #01-05          2.0
# 7         Genome@Biopolis #01-05,, 60 Biopolis Street          NaN
# 8                          8 Biomedical Grove, #01-06          NaN
# 9                                  37 Rochester Drive          2.0
# 10                118 Holland Avenue, #01-06, Raffles          2.0
# 11                                 275 Holland Avenue          2.0
# 12                        44 Jalan Merah Saga, #01-58          NaN
# 13       44 Jalan Merah Saga, #01-56 Chip Bee Gardens          2.0
# 14                                 26A Lorong Mambong          NaN
# 15                         15 Lorong Liput, Singapore          NaN
# 16  2A Lorong Mambong, Level 2 Above Little Farms ...          NaN
# 17  Holland Village Market #01-24, 1 Lorong Mambon...          NaN
# 18                                   1 Lorong Mambong          NaN
# 19                                   1 Lorong Mambong          NaN
# 20                        44 Jalan Merah Saga, #01-42          NaN
# 21                1 Lorong Mambong, #01-26, Singapore          NaN
# 22  211 Holland Avenue, #01-K4 Holland Road Shoppi...          NaN
# 23  211 Holland Ave, Holland Road Shopping Centre,...          NaN
# 24                                 118 Holland Avenue          NaN
# 25                         118 Holland Avenue, #01-03          NaN
# 26                                  48 Lorong Mambong          2.0
# 27                        43 Jalan Merah Saga, #01-74          2.0
# 28                                    31 Lorong Liput          NaN
# 29              One, 7 Holland Village Way, #01-29/30          NaN
# 30            7 Holland Village Way, #03-29 to 33 ONE          NaN
# 31  7 Holland Village Way, One, #01-55 Holland Vil...          NaN
# 32                          17B Lorong Liput, #277747          NaN
# 33                    One Holland Village Way, #02-07          NaN
# 34                  7 Holland Village Way, #01-56 One          2.0
# 35                                   25C Lorong Liput          NaN
# 36                                   17D Lorong Liput          NaN
# 37                      7 Holland Village Way, #01-06          2.0
# 38                   7 Holland Village Way, #02-25/26          NaN
# 39              7 Holland Village Way, #02-23/24, One          NaN
# 40                                   46 Holland Drive          NaN
# 41               46 Holland Drive, #01-359, Singapore          NaN
# 42                                    6 Holland Close          NaN
# 43     46 Holland Drive, Block 46 Block 46, Singapore          NaN
# 44                44 Holland Drive, #02-33, Singapore          NaN
# 45                            Holland Drive, Block 43          NaN
# 46                  44 Holland Drive, market and food          NaN
# 47                6 Holland Close, Block 6, Singapore          1.0
# 48       Holland Drive, #02-42 Market and Food Centre          NaN
# 49               44 Holland Drive, #02-25 Food Centre          NaN
# 50                            6 Holland Close, #01-36          NaN
# 51                            6 Holland Close, #01-20          NaN
# 52              31 Holland Close, Block 31, Singapore          NaN
# 53              31 Holland Close, Block 31, Singapore          NaN
# 54                 Holland Drive, Block 40, Singapore          NaN
# 55       40 Holland Drive, #01-39 Block 40, Singapore          NaN
# 56               43 Holland Drive, # 01-75, Singapore          NaN
# 57              43 Holland Drive, Block 43, Singapore          NaN
# 58                          43 Holland Drive, # 01-75          1.0
# 59            Blk 40 Holland Drive, #01-27, Singapore          NaN
#
#    permanently_closed neighborhood region
# 0                None       katong   west
# 1                None       katong   west
# 2                None       katong   west
# 3                None       katong   west
# 4                None       katong   west
# 5                None       katong   west
# 6                None       katong   west
# 7                None       katong   west
# 8                None       katong   west
# 9                None       katong   west
# 10               None       katong   west
# 11               None       katong   west
# 12               None       katong   west
# 13               None       katong   west
# 14               None       katong   west
# 15               None       katong   west
# 16               None       katong   west
# 17               None       katong   west
# 18               True       katong   west
# 19               None       katong   west
# 20               None       katong   west
# 21               None       katong   west
# 22               None       katong   west
# 23               None       katong   west
# 24               None       katong   west
# 25               None       katong   west
# 26               None       katong   west
# 27               None       katong   west
# 28               None       katong   west
# 29               None       katong   west
# 30               None       katong   west
# 31               None       katong   west
# 32               None       katong   west
# 33               None       katong   west
# 34               None       katong   west
# 35               None       katong   west
# 36               None       katong   west
# 37               None       katong   west
# 38               None       katong   west
# 39               None       katong   west
# 40               None       katong   west
# 41               None       katong   west
# 42               None       katong   west
# 43               None       katong   west
# 44               None       katong   west
# 45               None       katong   west
# 46               None       katong   west
# 47               None       katong   west
# 48               None       katong   west
# 49               None       katong   west
# 50               None       katong   west
# 51               None       katong   west
# 52               None       katong   west
# 53               None       katong   west
# 54               None       katong   west
# 55               None       katong   west
# 56               None       katong   west
# 57               None       katong   west
# 58               None       katong   west
# 59               None       katong   west

# %%
"""Test reviews collection for Holland Village cafes"""

from src.data.query import CafeQuery
import pandas as pd
from datetime import datetime

def test_reviews_collection():
    # Initialize
    print("Initializing...")
    cafe_query1 = CafeQuery()
    
    # First get cafes from one neighborhood
    test_neighborhood = {
        'center': [1.3088691, 103.9044623],
        'radius': 1200,
        'neighborhood_name': 'katong',
        'region': 'east'
    }
    
    print(f"\nGetting cafes from {test_neighborhood['neighborhood_name']}...")
    cafes_df = cafe_query1.collect_cafes(test_neighborhood)
    print(f"Found {len(cafes_df)} cafes")
    
    # Now get reviews for these cafes
    print(f"\nCollecting reviews for all cafes...")
    place_ids = cafes_df['place_id'].tolist()
    reviews_df = cafe_query1.collect_reviews(place_ids)
    
    print(f"\n✅ Collected {len(reviews_df)} total reviews")
    print(f"Average reviews per cafe: {len(reviews_df)/len(cafes_df):.1f}")
    
    # Merge neighborhood info into reviews
    reviews_df = reviews_df.merge(
        cafes_df[['place_id', 'neighborhood', 'region']],
        on='place_id',
        how='left'
    )
    
    # Save both datasets
    timestamp = datetime.now().strftime('%Y%m%d')
    
    cafes_path = f'data/cafes_katong_{timestamp}.parquet'
    reviews_path = f'data/reviews_katong_{timestamp}.parquet'
    
    cafes_df.to_parquet(cafes_path)
    reviews_df.to_parquet(reviews_path)
    
    print(f"\nData saved:")
    print(f"  Cafes: {cafes_path}")
    print(f"  Reviews: {reviews_path}")
    
    # Quick preview
    print("\nSample reviews:")
    print(reviews_df[['place_name', 'rating', 'text']].head(3))

if __name__ == "__main__":
    test_reviews_collection()
# Out:
# /Users/kailarecio/python_code/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Initializing...
# Client initialized and cafe reviews for 12 neighborhoods will be extracted
#
# Getting cafes from katong...
# Found 60 cafes
#
# Collecting reviews for all cafes...
#
# ✅ Collected 266 total reviews
# Average reviews per cafe: 4.4
#
# Data saved:
#   Cafes: data/cafes_katong_20250930.parquet
#   Reviews: data/reviews_katong_20250930.parquet
#
# Sample reviews:
#                     place_name  rating  \
# 0  Choice Cuts Pizza & Records       5
# 1  Choice Cuts Pizza & Records       4
# 2  Choice Cuts Pizza & Records       5
#
#                                                 text
# 0  There’s a real hustle and bustle energy in the...
# 1  Choice Cut nails the New York-style pizza vibe...
# 2  I had a pizza from them and I enjoyed it! Pric...

# %%
df_katong = pd.read_parquet('data/reviews_katong_20250930.parquet')
df_katong
# Out:
#                         place_id                   place_name  \
# 0    ChIJp0cob88Z2jER6mvxImemres  Choice Cuts Pizza & Records
# 1    ChIJp0cob88Z2jER6mvxImemres  Choice Cuts Pizza & Records
# 2    ChIJp0cob88Z2jER6mvxImemres  Choice Cuts Pizza & Records
# 3    ChIJp0cob88Z2jER6mvxImemres  Choice Cuts Pizza & Records
# 4    ChIJp0cob88Z2jER6mvxImemres  Choice Cuts Pizza & Records
# ..                           ...                          ...
# 261  ChIJh9We8VkZ2jERoBWE-LhhvI0        Butter & Spice Katong
# 262  ChIJh9We8VkZ2jERoBWE-LhhvI0        Butter & Spice Katong
# 263  ChIJh9We8VkZ2jERoBWE-LhhvI0        Butter & Spice Katong
# 264  ChIJR34pKgAZ2jERF6MoGw4mk0A    Alishan Taiwanese Cuisine
# 265  ChIJR34pKgAZ2jERF6MoGw4mk0A    Alishan Taiwanese Cuisine
#
#           author_name                                         author_url  \
# 0         Howcan Eats  https://www.google.com/maps/contrib/1122892009...
# 1              Yordan  https://www.google.com/maps/contrib/1117947906...
# 2             Marek B  https://www.google.com/maps/contrib/1101141077...
# 3       Maila Cabatic  https://www.google.com/maps/contrib/1053578725...
# 4           Daniel Ng  https://www.google.com/maps/contrib/1079990664...
# ..                ...                                                ...
# 261  Andrew Augustine  https://www.google.com/maps/contrib/1169233140...
# 262        Arnold Teo  https://www.google.com/maps/contrib/1162119341...
# 263       Kester Chan  https://www.google.com/maps/contrib/1013444622...
# 264           Jed Lim  https://www.google.com/maps/contrib/1172530796...
# 265          Karen Ng  https://www.google.com/maps/contrib/1129064723...
#
#      rating                                               text        time  \
# 0         5  There’s a real hustle and bustle energy in the...  1756036634
# 1         4  Choice Cut nails the New York-style pizza vibe...  1747588967
# 2         5  I had a pizza from them and I enjoyed it! Pric...  1757258839
# 3         5  Loved the NYC-style pizza. Felt like I was bac...  1752717664
# 4         5  Lovely little New York style pizza joint!! The...  1746704597
# ..      ...                                                ...         ...
# 261       5  This spot is apparently popular among locals a...  1750160457
# 262       5  One of the best places in Singapore to get you...  1756654323
# 263       5  Our usual go-to for some Indian cuisine fix!\n...  1733675060
# 264       3  Simple Taiwanese fare of braised pork belly ri...  1729856228
# 265       5               Generous portions serve pipping hot.  1736070145
#
#     relative_time_description neighborhood region
# 0                 a month ago       katong   east
# 1                4 months ago       katong   east
# 2                 3 weeks ago       katong   east
# 3                2 months ago       katong   east
# 4                4 months ago       katong   east
# ..                        ...          ...    ...
# 261              3 months ago       katong   east
# 262               4 weeks ago       katong   east
# 263              9 months ago       katong   east
# 264             11 months ago       katong   east
# 265              8 months ago       katong   east
#
# [266 rows x 10 columns]

# %% [markdown]
# columns needed: place_id, place_name, author_name, author_url (if author_url is unique, no need author_name), text, relative_time_description, neighborhood and region

# %%
sample_reviews = pd.read_parquet('data/raw/reviews_20250930.parquet')
sample_reviews.head()
# Out:
#                       place_id                    place_name author_id  \
# 0  ChIJW-HHrWwZ2jERC16smRC_0NQ  Carlton City Hotel Singapore   reviews
# 1  ChIJW-HHrWwZ2jERC16smRC_0NQ  Carlton City Hotel Singapore   reviews
# 2  ChIJW-HHrWwZ2jERC16smRC_0NQ  Carlton City Hotel Singapore   reviews
# 3  ChIJW-HHrWwZ2jERC16smRC_0NQ  Carlton City Hotel Singapore   reviews
# 4  ChIJW-HHrWwZ2jERC16smRC_0NQ  Carlton City Hotel Singapore   reviews
#
#    rating                                               text review_date  \
# 0       5  Great experience at the Carlton City. Clean, b...  2025-06-06
# 1       4  Stayed at Carlton City Hotel from Saturday to ...  2025-09-15
# 2       1  The rooms are ok. But a five star hotel should...  2025-08-18
# 3       3  We did encounter a couple of minor issues – th...  2025-07-19
# 4       5  I personally really enjoyed our stay at Carlto...  2025-08-19
#
#   relative_time_description neighborhood   region
# 0              3 months ago          cbd  central
# 1               2 weeks ago          cbd  central
# 2               a month ago          cbd  central
# 3              2 months ago          cbd  central
# 4               a month ago          cbd  central

# %%
len(sample_reviews)
# Out:
# 2886

# %%
sample_cafes = pd.read_parquet('data/raw/cafes_20250930.parquet')
sample_cafes.head()
# Out:
#                                                 name  \
# 0                       Carlton City Hotel Singapore
# 1                                      The Book Cafe
# 2                                 Tiong Bahru Bakery
# 3                                       Nylon Coffee
# 4  The FernTree Café - International Buffet Singa...
#
#                       place_id  rating  user_ratings_total  price_level  \
# 0  ChIJW-HHrWwZ2jERC16smRC_0NQ     4.4              2272.0          NaN
# 1  ChIJm-22KpwZ2jERHav69tu9J48     4.3              1247.0          2.0
# 2  ChIJ--NsrnAZ2jER-Ry6WJB26Uo     4.3              3181.0          2.0
# 3  ChIJE7ZtOWwZ2jERFcasWYmljJQ     4.7              2100.0          1.0
# 4  ChIJk2JMPHYZ2jERS2cY70LXric     4.4               416.0          2.0
#
#                                                types business_status  \
# 0  [bar, cafe, lodging, restaurant, food, point_o...     OPERATIONAL
# 1  [cafe, restaurant, food, point_of_interest, es...     OPERATIONAL
# 2  [cafe, meal_delivery, meal_takeaway, bakery, r...     OPERATIONAL
# 3  [cafe, food, point_of_interest, store, establi...     OPERATIONAL
# 4  [restaurant, cafe, food, point_of_interest, es...     OPERATIONAL
#
#   permanently_closed neighborhood   region
# 0               None          cbd  central
# 1               None          cbd  central
# 2               None          cbd  central
# 3               None          cbd  central
# 4               None          cbd  central

# %%
len(sample_cafes)
# Out:
# 658
